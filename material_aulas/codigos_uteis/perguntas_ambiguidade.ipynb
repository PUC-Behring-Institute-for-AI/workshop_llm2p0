# %%
from ollama import chat

MODEL = "qwen3.5:9b"

examples = [

    "Vi o homem com o telescópio. Quem estava com o telescópio?",

    "Maria colocou o livro na mochila porque ela era pequena. Quem era pequena?",

    "João encontrou Pedro quando ele saiu da escola. Quem saiu da escola?",

    "João contou para Marcos que havia sido aprovado por ele. Quem foi aprovado?"

]

for example in examples:

    print("="*70)

    print(example)

    print()

    response = chat(

        model=MODEL,

        messages=[
            {
                "role":"user",
                "content":example
            }
        ]
    )

    print(response["message"]["content"])
# Out:
# ======================================================================
# Vi o homem com o telescópio. Quem estava com o telescópio?
#
# Com base na frase fornecida, a interpretação mais comum e direta em português associa o objeto (o telescópio) ao sujeito mencionado imediatamente antes da preposição "com". Portanto, sem informação de outra pessoa presente no texto, a resposta é que estava com o telescópio **o homem**.
#
# **Resposta:** O homem.
# ======================================================================
# Maria colocou o livro na mochila porque ela era pequena. Quem era pequena?
#
# A frase "Maria colocou o livro na mochila porque ela era pequena" apresenta uma **ambiguidade de referência** para a pronome "ela". Isso ocorre porque existem dois substantivos femininos no contexto: *Maria* (pessoa) e *mochila* (objeto). Contudo, as regras de resolução referencial da língua portuguesa levam à conclusão mais provável.
#
# Geralmente, na ausência de outro contexto específico ou indicação gramatical adicional (como repetição do nome), o pronome "ela" tende a se referir ao **sujeito principal** e/ou seres animados em detrimento dos objetos inanimados devido ao princípio da hierarquia animática:
# 1.  Maria = Substantivo próprio de pessoa feminina + Sujeito.
# 2.  Mochila = Substantivo comum feminino (objeto).
#
# Portanto, a interpretação padrão é que **Maria** era pequena.
#
# No entanto, dependendo do contexto conversacional prévio ou da ênfase na capacidade/propriedade da mochila (ex: "ela [a mochila] cabia pouco"), poderia ser interpretada como referindo-se à própria **mochila**, embora seja menos comum usar apenas o pronome sem artigo ("aquela") para um objeto neste tipo de frase.
#
# **Resposta:** A interpretação gramatical padrão aponta que era a **Maria**. (Ambiguidade possível apontando à mochila).
# ======================================================================
# João encontrou Pedro quando ele saiu da escola. Quem saiu da escola?
#
# Essa frase é um exemplo clássico de **ambiguidade referencial** em linguagem natural (similar ao que aparece nos "Winograd Schemas"). Gramaticalmente e semanticamente a resposta não pode ser determinada com certeza absoluta apenas com essas informações.
#
# A pronome **"ele"** pode se referir a:
# 1.  **Pedro:** A frase significa que João encontrou Pedro no momento exato em que o próprio **Pedro** saiu da escola (talvez João estivesse esperando na saída).
# 2.  **João:** A frase também seria gramaticalmente correta e possível, significando que João estava saindo da escola e aí aconteceu de encontrar Pedro (ou ambos saíram juntos naquele momento, ou João viu o Pedro enquanto ia para casa após sair do prédio escolar junto a ele? Ou talvez apenas coincidiram na saída).
#
# Sem contexto adicional sobre onde eles estavam antes desse evento, não há como distinguir. Porém, no uso cotidiano da linguagem:
# *   É comum associar "encontrou X" à ação de "Y estava deixando o lugar".
# *   Assim que se usa a frase para descrever um encontro na saída de um prédio escolar por coincidência de horários ou encontros sociais (como esperar alguém), costuma-se referir ao outro como quem está saindo.
#
# **Conclusão:** A pergunta correta é: **Ambos os casos são possíveis**, mas depende do contexto real que não foi fornecido na frase para resolver o "ele".
# ======================================================================
# João contou para Marcos que havia sido aprovado por ele. Quem foi aprovado?
#
# A frase contém uma ambigüidade de referência linguística. Não é possível determinar com certeza absoluta quem foi aprovado apenas com base na informação gramatical dada, pois o pronome "ele" pode se referir a qualquer um dos dois sujeitos mencionados anteriormente (**João** ou **Marcos**), dependendo do contexto que não está explícito no texto original (por exemplo: qual deles era responsável pela aprovação).
#
# Portanto, tecnicamente, podemos considerar duas interpretações principais baseadas apenas na sintaxe e sem mais contexto:
# 1.  João foi aprovado por Marcos (exemplo de uma situação onde o outro tem poder de julgamento sobre ele?).
# 2.  Marco? Se "por ele" for alguém do terceiro não mencionado...
#
# Mas se a pergunta é um teste lógico clássico: **Não há como saber**. A frase é ambígua quanto à resolução anafórica dos pronomes em português ("problema da referência").
